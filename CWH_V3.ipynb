# %% [markdown]
# <a href="https://colab.research.google.com/github/tasnimislamraisa/Python_Learning/blob/edupython/CWH_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arr=np.arange(1000000)

# %%
 pythlist=list(range(1000000))

# %%
# %time for _ in range(10): [item*3 for item in pythlist]
# Out:
# CPU times: user 418 ms, sys: 203 ms, total: 620 ms
# Wall time: 622 ms

# %%
# %time for _ in range(10):arr =arr*3
# Out:
# CPU times: user 17.8 ms, sys: 6.88 ms, total: 24.7 ms
# Wall time: 27.8 ms

# %%
np.array([3,5,6,7,8,9])
# Out:
# array([3, 5, 6, 7, 8, 9])
